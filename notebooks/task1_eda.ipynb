# %%
import importlib
import src.cleaning

importlib.reload(src.cleaning)
# Out:
# <module 'src.cleaning' from 'c:\\Users\\Liya Daniel\\Desktop\\week1\\src\\cleaning.py'>

# %%
import sys
import os

sys.path.insert(0, os.path.abspath('..'))

from src.data_loader import load_data
from src.cleaning import remove_nulls
from src.cleaning import normalize_timezone
import src.eda as eda

# %%
df = load_data(
    '../data/raw/news.csv',
    index_col=0,
    parse_dates=['date']
)

# %%
df = normalize_timezone(df, 'date')

# %%
df = remove_nulls(df)

# %%
eda.publisher_counts(df).head(10)
# Out:
# publisher
# Paul Quintaro        228373
# Lisa Levin           186979
# Benzinga Newsdesk    150484
# Charles Gross         96732
# Monica Gerson         82380
# Eddie Staley          57254
# Hal Lindon            49047
# ETF Professor         28489
# Juan Lopez            28438
# Benzinga Staff        28114
# Name: count, dtype: int64

# %%
eda.headline_length_stats(df)
# Out:
# count    1.407328e+06
# mean     7.312051e+01
# std      4.073531e+01
# min      3.000000e+00
# 25%      4.700000e+01
# 50%      6.400000e+01
# 75%      8.700000e+01
# max      5.120000e+02
# Name: headline, dtype: float64

# %%
eda.extract_common_keywords(df['headline'])
# Out:
# [('vs', 162099),
#  ('stocks', 161776),
#  ('est', 140604),
#  ('eps', 128897),
#  ('market', 120558),
#  ('shares', 114313),
#  ('reports', 108710),
#  ('update', 91723),
#  ('earnings', 87399),
#  ('sales', 79645),
#  ('benzinga', 74516),
#  ('pt', 73068),
#  ('week', 69572),
#  ('announces', 66591),
#  ('price', 64407),
#  ('buy', 64371),
#  ('mid', 62263),
#  ('downgrades', 61959),
#  ('trading', 61182),
#  ('raises', 57802)]

# %%
freq = eda.article_frequency_over_time(df)

freq.plot(figsize=(12,5))
# Out:
# <Axes: xlabel='date'>
